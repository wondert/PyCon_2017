# %% [markdown]
# <b> This notebook contains the sample code for a simple RSS Feed parser </b>

# %%
import feedparser
import os
import pandas as pd

from datetime import datetime

# %%
# set the feeds as global variables
ITUNES = "http://ax.itunes.apple.com/WebObjects/MZStoreServices.woa/ws/RSS/topMovies/xml"
NETFLIX = "http://dvd.netflix.com/Top100RSS"
RSS_LIST = [ITUNES, NETFLIX]

# %%
# set the dataframe columns as global variables
DF_COLUMNS = ['source', 'date', 'rank', 'title', 'link', 'summary']

# %%
# create a function to parse data and append to a dataframe
def top10_movies(rss, df):
    
    #parse the feed
    #In order to understand feed, need to read the api. 
    #Lots of info not included in notebook (what are the feed. methods? what do they call?)
    #See cells below for details!!!
    feed = feedparser.parse(rss)
    
    #check bozo to see if your feed is well formed
    if feed.bozo == 0:
        print("%s is a well-formed feed!" % feed.feed.title)
    else:
        print("%s has flipped the bozo bit. Potential errors ahead!" % feed.feed.title)
        
    #set the feed date to be the published data, if it exists. If not, use the current date
    feed_date = feed.feed.get('published', datetime.now().strftime('%Y-%m-%d'))
    
    #set a counter for our loop
    i = 0
    
    #for the first 10 movies in our feed, append the required information to the dataframe
    #dataframe columns were set in the DF_COLUMNS global var above (source, date, rank, title, link, summary)
    while i < 10:
        feed_items = pd.Series([feed.feed.title, feed_date, i+1, feed.entries[i].title, feed.entries[i].id, \
                              feed.entries[i].summary], DF_COLUMNS)
        df = df.append(feed_items, ignore_index = True)
        i+= 1
    
    #return the dataframe
    return df

if __name__ == "__main__":
    #create an empty dataframe
    top10_df = pd.DataFrame(columns = DF_COLUMNS)
    
    #run each feed through our top 10 function
    for item in RSS_LIST:
        top10_df = top10_movies(item, top10_df)
        
    #save the dataframe to a csv. if the csv exists, append to it
    if not os.path.isfile('top10.csv'):
        top10_df.to_csv('top10.csv', header = DF_COLUMNS, index = False)
    else:
        top10_df.to_csv('top10.csv', mode = 'a', header = False, index = False)
# Out:
# iTunes Store: Top Movies is a well-formed feed!
# Netflix Top 100 is a well-formed feed!

# %% [markdown]
# <b> Lets explore the feedparser api methods! </b>

# %%
# What elements are available in the ITunes RSS Feed?
itunes_parse = feedparser.parse('http://ax.itunes.apple.com/WebObjects/MZStoreServices.woa/ws/RSS/topMovies/xml')
itunes_parse.feed
# Out:
# {'author': 'iTunes Store',
#  'author_detail': {'href': 'http://www.apple.com/itunes/',
#   'name': 'iTunes Store'},
#  'authors': [{'href': 'http://www.apple.com/itunes/', 'name': 'iTunes Store'}],
#  'guidislink': True,
#  'href': 'http://www.apple.com/itunes/',
#  'icon': 'http://itunes.apple.com/favicon.ico',
#  'id': 'http://ax.itunes.apple.com/WebObjects/MZStoreServices.woa/ws/RSS/topMovies/xml',
#  'language': 'en',
#  'link': 'https://itunes.apple.com/WebObjects/MZStore.woa/wa/viewTop?cc=us&id=1&popId=15',
#  'links': [{'href': 'https://itunes.apple.com/WebObjects/MZStore.woa/wa/viewTop?cc=us&id=1&popId=15',
#    'rel': 'alternate',
#    'type': 'text/html'},
#   {'href': 'http://ax.itunes.apple.com/WebObjects/MZStoreServices.woa/ws/RSS/topMovies/xml',
#    'rel': 'self',
#    'type': 'application/atom+xml'}],
#  'rights': 'Copyright 2008 Apple Inc.',
#  'rights_detail': {'base': 'http://ax.itunes.apple.com/WebObjects/MZStoreServices.woa/ws/RSS/topMovies/xml',
#   'language': 'en',
#   'type': 'text/plain',
#   'value': 'Copyright 2008 Apple Inc.'},
#  'title': 'iTunes Store: Top Movies',
#  'title_detail': {'base': 'http://ax.itunes.apple.com/WebObjects/MZStoreServices.woa/ws/RSS/topMovies/xml',
#   'language': 'en',
#   'type': 'text/plain',
#   'value': 'iTunes Store: Top Movies'},
#  'updated': '2017-06-05T21:49:17-07:00',
#  'updated_parsed': time.struct_time(tm_year=2017, tm_mon=6, tm_mday=6, tm_hour=4, tm_min=49, tm_sec=17, tm_wday=1, tm_yday=157, tm_isdst=0)}

# %%
# Is the feed a dict?
type(itunes_parse.feed)
# Out:
# feedparser.FeedParserDict

# %%
# What are the keys available (we can clearly see from the .feed printout, but this is for funzies)
itunes_parse.feed.keys()
# Out:
# dict_keys(['language', 'id', 'guidislink', 'link', 'title', 'title_detail', 'updated', 'updated_parsed', 'links', 'icon', 'authors', 'author_detail', 'href', 'author', 'rights', 'rights_detail'])

# %%
# What is the feed.bozo????
itunes_parse.feed.bozo
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# D:\Rafael\Anaconda\lib\site-packages\feedparser.py in __getattr__(self, key)
#     397         try:
# --> 398             return self.__getitem__(key)
#     399         except KeyError:
#
# D:\Rafael\Anaconda\lib\site-packages\feedparser.py in __getitem__(self, key)
#     355                 return dict.__getitem__(self, realkey)
# --> 356         return dict.__getitem__(self, key)
#     357
#
# KeyError: 'bozo'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-31-53fa1df466bb> in <module>()
#       1 #What is the feed.bozo????
# ----> 2 if itunes_parse.feed.bozo:
#       3     print('the bozo exists')
#       4 else:
#       5     print('the bozo is absent')
#
# D:\Rafael\Anaconda\lib\site-packages\feedparser.py in __getattr__(self, key)
#     398             return self.__getitem__(key)
#     399         except KeyError:
# --> 400             raise AttributeError("object has no attribute '%s'" % key)
#     401
#     402     def __hash__(self):
#
# AttributeError: object has no attribute 'bozo'

# %%
# Feedparser docs indicate the bozo bit is a value assigned when the rss feed in not well-formated XML.
wellformed = feedparser.parse('http://feedparser.org/docs/examples/atom10.xml')
notwellformed = feedparser.parse('http://feedparser.org/tests/illformed/rss/aaa_illformed.xml')

print("A well formed rss will yield {} whilst a non-well formed rss yields the value {}. \
Bozo may also not be present, but this does not always indicate poor formating".format(wellformed.bozo-1, notwellformed.bozo))
# Out:
# A well formed rss will yield 0 whilst a non-well formed rss yields the value 1. Bozo may also not be present, but this does not always indicate poor formating

# %%
# Lets have a look at Netflix!
netflix_parse = feedparser.parse('http://dvd.netflix.com/Top100RSS')
netflix_parse.feed
# Out:
# {'cf_treatas': 'list',
#  'language': 'en-us',
#  'link': 'http://dvd.netflix.com',
#  'links': [{'href': 'http://dvd.netflix.com',
#    'rel': 'alternate',
#    'type': 'text/html'},
#   {'href': 'http://dvd.netflix.com/Top100RSS',
#    'rel': 'self',
#    'type': 'application/rss+xml'}],
#  'subtitle': 'Top 100 Netflix movies, published every 2 weeks.',
#  'subtitle_detail': {'base': 'http://dvd.netflix.com/Top100RSS',
#   'language': None,
#   'type': 'text/html',
#   'value': 'Top 100 Netflix movies, published every 2 weeks.'},
#  'title': 'Netflix Top 100',
#  'title_detail': {'base': 'http://dvd.netflix.com/Top100RSS',
#   'language': None,
#   'type': 'text/plain',
#   'value': 'Netflix Top 100'},
#  'ttl': '20160'}

# %%
# The feed method returns a python dictionary!
isinstance(netflix_parse.feed, dict)
# Out:
# True

# %%
# The entries method returns a list of dicts. Each dict contains the metadata associated with each movie
netflix_parse.entries
# Out:
# [{'guidislink': False,
#   'id': 'https://dvd.netflix.com/Movie/Sully/80103102',
#   'link': 'https://dvd.netflix.com/Movie/Sully/80103102',
#   'links': [{'href': 'https://dvd.netflix.com/Movie/Sully/80103102',
#     'rel': 'alternate',
#     'type': 'text/html'}],
#   'summary': '<a href="https://dvd.netflix.com/Movie/Sully/80103102"><img src="//secure.netflix.com/us/boxshots/small/80103102.jpg"/></a><br>Viewers around the world were astonished in 2009 when airline pilot Chesley Sullenberger safely landed an Airbus 320 on the Hudson River after both engines were disabled. This fact-based drama illuminates Sullenberger\'s life and heroic achievement.',
#   'summary_detail': {'base': 'http://dvd.netflix.com/Top100RSS',
#    'language': None,
#    'type': 'text/html',
#    'value': '<a href="https://dvd.netflix.com/Movie/Sully/80103102"><img src="//secure.netflix.com/us/boxshots/small/80103102.jpg"/></a><br>Viewers around the world were astonished in 2009 when airline pilot Chesley Sullenberger safely landed an Airbus 320 on the Hudson River after both engines were disabled. This fact-based drama illuminates Sullenberger\'s life and heroic achievement.'},
#   'title': 'Sully',
#   'title_detail': {'base': 'http://dvd.netflix.com/Top100RSS',
#    'language': None,
#    'type': 'text/plain',
#    'value': 'Sully'}},
#  {'guidislink': False,
#   'id': 'https://dvd.netflix.com/Movie/Hacksaw-Ridge/80108975',
#   'link': 'https://dvd.netflix.com/Movie/Hacksaw-Ridge/80108975',
#   'links': [{'href': 'https://dvd.netflix.com/Movie/Hacksaw-Ridge/80108975',
#     'rel': 'alternate',
#     'type': 'text/html'}],
#   'summary': '<a href="https://dvd.netflix.com/Movie/Hacksaw-Ridge/80108975"><img src="//secure.netflix.com/us/boxshots/small/80108975.jpg"/></a><br>Based on a true story, this World War II drama focuses on Desmond T. Doss, a conscientious objector who becomes a hero while serving as an unarmed medic during the brutal and bloody fight for Okinawa.',
#   'summary_detail': {'base': 'http://dvd.netflix.com/Top100RSS',
#    'language': None,
#    'type': 'text/html',
#    'value': '<a href="https://dvd.netflix.com/Movie/Hacksaw-Ridge/80108975"><img src="//secure.netflix.com/us/boxshots/small/80108975.jpg"/></a><br>Based on a true story, this World War II drama focuses on Desmond T. Doss, a conscientious objector who becomes a hero while serving as an unarmed medic during the brutal and bloody fight for Okinawa.'},
#   'title': 'Hacksaw Ridge',
#   'title_detail': {'base': 'http://dvd.netflix.com/Top100RSS',
#    'language': None,
#    'type': 'text/plain',
#    'value': 'Hacksaw Ridge'}},
#  {'guidislink': False,
#   'id': 'https://dvd.netflix.com/Movie/The-Accountant/80071227',
#   'link': 'https://dvd.netflix.com/Movie/The-Accountant/80071227',
#   'links': [{'href': 'https://dvd.netflix.com/Movie/The-Accountant/80071227',
#     'rel': 'alternate',
#     'type': 'text/html'}],
#   'summary': '<a href="https://dvd.netflix.com/Movie/The-Accountant/80071227"><img src="//secure.netflix.com/us/boxshots/small/80071227.jpg"/></a><br>Offering two very different skills to his clients, a financial forensics expert and trained assassin goes to work for a tech mogul who\'s determined to eliminate those responsible for secretly manipulating the company\'s financial records.',
#   'summary_detail': {'base': 'http://dvd.netflix.com/Top100RSS',
#    'language': None,
#    'type': 'text/html',
#    'value': '<a href="https://dvd.netflix.com/Movie/The-Accountant/80071227"><img src="//secure.netflix.com/us/boxshots/small/80071227.jpg"/></a><br>Offering two very different skills to his clients, a financial forensics expert and trained assassin goes to work for a tech mogul who\'s determined to eliminate those responsible for secretly manipulating the company\'s financial records.'},
#   'title': 'The Accountant',
#   'title_detail': {'base': 'http://dvd.netflix.com/Top100RSS',
#    'language': None,
#    'type': 'text/plain',
#    'value': 'The Accountant'}},
#  {'guidislink': False,
#   'id': 'https://dvd.netflix.com/Movie/Jason-Bourne/80098202',
#   'link': 'https://dvd.netflix.com/Movie/Jason-Bourne/80098202',
#   'links': [{'href': 'https://dvd.netflix.com/Movie/Jason-Bourne/80098202',
#     'rel': 'alternate',
#     'type': 'text/html'}],
#   'summary': '<a href="https://dvd.netflix.com/Movie/Jason-Bourne/80098202"><img src="//secure.netflix.com/us/boxshots/small/80098202.jpg"/></a><br>Back for another high-stakes, high-octane thriller, superspy Jason Bourne plays cat and mouse with covert government agencies and terrorist rings while edging closer to unraveling the mystery of his real identity.',
#   'summary_detail': {'base': 'http://dvd.netflix.com/Top100RSS',
#    'language': None,
#    'type': 'text/html',
#    'value': '<a href="https://dvd.netflix.com/Movie/Jason-Bourne/80098202"><img src="//secure.netflix.com/us/boxshots/small/80098202.jpg"/></a><br>Back for another high-stakes, high-octane thriller, superspy Jason Bourne plays cat and mouse with covert government agencies and terrorist rings while edging closer to unraveling the mystery of his real identity.'},
#   'title': 'Jason Bourne',
#   'title_detail': {'base': 'http://dvd.netflix.com/Top100RSS',
#    'language': None,
#    'type': 'text/plain',
#    'value': 'Jason Bourne'}},
#  {'guidislink': False,
#   'id': 'https://dvd.netflix.com/Movie/The-Magnificent-Seven/80104000',
#   'link': 'https://dvd.netflix.com/Movie/The-Magnificent-Seven/80104000',
#   'links': [{'href': 'https://dvd.netflix.com/Movie/The-Magnificent-Seven/80104000',
#     'rel': 'alternate',
#     'type': 'text/html'}],
#   'summary': '<a href="https://dvd.netflix.com/Movie/The-Magnificent-Seven/80104000"><img src="//secure.netflix.com/us/boxshots/small/80104000.jpg"/></a><br>In this remake of the rousing 1960 Western, a motley group of gunslingers comes together to protect the residents of a mining town, who are being terrorized and victimized by a ruthless gold tycoon and his gang of thugs.',
#   'summary_detail': {'base': 'http://dvd.netflix.com/Top100RSS',
#    'language': None,
#    'type': 'text/html',
#    'value': '<a href="https://dvd.netflix.com/Movie/The-Magnificent-Seven/80104000"><img src="//secure.netflix.com/us/boxshots/small/80104000.jpg"/></a><br>In this remake of the rousing 1960 Western, a motley group of gunslingers comes together to protect the residents of a mining town, who are being terrorized and victimized by a ruthless gold tycoon and his gang of thugs.'},
#   'title': 'The Magnificent Seven',
#   'title_detail': {'base': 'http://dvd.netflix.com/Top100RSS',
#    'language': None,
#    'type': 'text/plain',
#    'value': 'The Magnificent Seven'}},
#  {'guidislink': False,
#   'id': 'https://dvd.netflix.com/Movie/Game-of-Thrones/70177064',
#   'link': 'https://dvd.netflix.com/Movie/Game-of-Thrones/70177064',
#   'links': [{'href': 'https://dvd.netflix.com/Movie/Game-of-Thrones/70177064',
#     'rel': 'alternate',
#     'type': 'text/html'}],
#   'summary': '<a href="https://dvd.netflix.com/Movie/Game-of-Thrones/70177064"><img src="//secure.netflix.com/us/boxshots/small/70177064.jpg"/></a><br>Originally airing on HBO, this live-action fantasy series -- based on George R.R. Martin\'s "A Song of Ice and Fire" novels -- charts the violent efforts of competing noble families to gain control of the vacant Westeros throne.',
#   'summary_detail': {'base': 'http://dvd.netflix.com/Top100RSS',
#    'language': None,
#    'type': 'text/html',
#    'value': '<a href="https://dvd.netflix.com/Movie/Game-of-Thrones/70177064"><img src="//secure.netflix.com/us/boxshots/small/70177064.jpg"/></a><br>Originally airing on HBO, this live-action fantasy series -- based on George R.R. Martin\'s "A Song of Ice and Fire" novels -- charts the violent efforts of competing noble families to gain control of the vacant Westeros throne.'},
#   'title': 'Game of Thrones',
#   'title_detail': {'base': 'http://dvd.netflix.com/Top100RSS',
#    'language': None,
#    'type': 'text/plain',
#    'value': 'Game of Thrones'}},
#  {'guidislink': False,
#   'id': 'https://dvd.netflix.com/Movie/Manchester-by-the-Sea/80097527',
#   'link': 'https://dvd.netflix.com/Movie/Manchester-by-the-Sea/80097527',
#   'links': [{'href': 'https://dvd.netflix.com/Movie/Manchester-by-the-Sea/80097527',
#     'rel': 'alternate',
#     'type': 'text/html'}],
#   'summary': '<a href="https://dvd.netflix.com/Movie/Manchester-by-the-Sea/80097527"><img src="//secure.netflix.com/us/boxshots/small/80097527.jpg"/></a><br>While working as a handyman in Boston, taciturn loner Lee Chandler gets word that his brother Joe has died of a coronary. After returning to the siblings\' hometown, Lee receives another shock: He\'s been named legal guardian of Joe\'s 16-year-old son.',
#   'summary_detail': {'base': 'http://dvd.netflix.com/Top100RSS',
#    'language': None,
#    'type': 'text/html',
#    'value': '<a href="https://dvd.netflix.com/Movie/Manchester-by-the-Sea/80097527"><img src="//secure.netflix.com/us/boxshots/small/80097527.jpg"/></a><br>While working as a handyman in Boston, taciturn loner Lee Chandler gets word that his brother Joe has died of a coronary. After returning to the siblings\' hometown, Lee receives another shock: He\'s been named legal guardian of Joe\'s 16-year-old son.'},
#   'title': 'Manchester by the Sea',
#   'title_detail': {'base': 'http://dvd.netflix.com/Top100RSS',
#    'language': None,
#    'type': 'text/plain',
#    'value': 'Manchester by the Sea'}},
#  {'guidislink': False,
#   'id': 'https://dvd.netflix.com/Movie/Deepwater-Horizon/80104412',
#   'link': 'https://dvd.netflix.com/Movie/Deepwater-Horizon/80104412',
#   'links': [{'href': 'https://dvd.netflix.com/Movie/Deepwater-Horizon/80104412',
#     'rel': 'alternate',
#     'type': 'text/html'}],
#   'summary': '<a href="https://dvd.netflix.com/Movie/Deepwater-Horizon/80104412"><img src="//secure.netflix.com/us/boxshots/small/80104412.jpg"/></a><br>Replaying the catastrophic explosion of the Deepwater Horizon oil rig in 2010, this tense drama recounts the horrific experiences of the 126 crew members onboard and the numerous acts of courage that saved untold lives.',
#   'summary_detail': {'base': 'http://dvd.netflix.com/Top100RSS',
#    'language': None,
#    'type': 'text/html',
#    'value': '<a href="https://dvd.netflix.com/Movie/Deepwater-Horizon/80104412"><img src="//secure.netflix.com/us/boxshots/small/80104412.jpg"/></a><br>Replaying the catastrophic explosion of the Deepwater Horizon oil rig in 2010, this tense drama recounts the horrific experiences of the 126 crew members onboard and the numerous acts of courage that saved untold lives.'},
#   'title': 'Deepwater Horizon',
#   'title_detail': {'base': 'http://dvd.netflix.com/Top100RSS',
#    'language': None,
#    'type': 'text/plain',
#    'value': 'Deepwater Horizon'}},
#  {'guidislink': False,
#   'id': 'https://dvd.netflix.com/Movie/Hell-or-High-Water/80108616',
#   'link': 'https://dvd.netflix.com/Movie/Hell-or-High-Water/80108616',
#   'links': [{'href': 'https://dvd.netflix.com/Movie/
',
#   'summary_detail': {'base': 'http://dvd.netflix.com/Top100RSS',
#    'language': None,
#    'type': 'text/html',
#    'value': '<a href="https://dvd.netflix.com/Movie/Suicide-Squad/80091595"><img src="//secure.netflix.com/us/boxshots/small/80091595.jpg"/></a><br>In this thrill-packed visit to the dark side of the DC Comics universe, a covert government organization drafts a team of jailed supervillains to carry out black ops missions in return for clemency.'},
#   'title': 'Suicide Squad',
#   'title_detail': {'base': 'http://dvd.netflix.com/Top100RSS',
#    'language': None,
#    'type': 'text/plain',
#    'value': 'Suicide Squad'}},
#  {'guidislink': False,
#   'id': 'https://dvd.netflix.com/Movie/Homeland/70180387',
#   'link': 'https://dvd.netflix.com/Movie/Homeland/70180387',
#   'links': [{'href': 'https://dvd.netflix.com/Movie/Homeland/70180387',
#     'rel': 'alternate',
#     'type': 'text/html'}],
#   'summary': '<a href="https://dvd.netflix.com/Movie/Homeland/70180387"><img src="//secure.netflix.com/us/boxshots/small/70180387.jpg"/></a><br>When Sgt. Nicholas Brody, an American prisoner of war, returns home after eight years of captivity, frantic CIA agent Carrie Anderson suspects the Marine of having been turned into an Al Qaeda terrorist in this espionage drama from Showtime.',
#   'summary_detail': {'base': 'http://dvd.netflix.com/Top100RSS',
#    'language': None,
#    'type': 'text/html',
#    'value': '<a href="https://dvd.netflix.com/Movie/Homeland/70180387"><img src="//secure.netflix.com/us/boxshots/small/70180387.jpg"/></a><br>When Sgt. Nicholas Brody, an American prisoner of war, returns home after eight years of captivity, frantic CIA agent Carrie Anderson suspects the Marine of having been turned into an Al Qaeda terrorist in this espionage drama from Showtime.'},
#   'title': 'Homeland',
#   'title_detail': {'base': 'http://dvd.netflix.com/Top100RSS',
#    'language': None,
#    'type': 'text/plain',
#    'value': 'Homeland'}},
#  {'guidislink': False,
#   'id': 'https://dvd.netflix.com/Movie/The-Secret-Life-of-Pets/80095314',
#   'link': 'https://dvd.netflix.com/Movie/The-Secret-Life-of-Pets/80095314',
#   'links': [{'href': 'https://dvd.netflix.com/Movie/The-Secret-Life-of-Pets/80095314',
#     'rel': 'alternate',
#     'type': 'text/html'}],
#   'summary': '<a href="https://dvd.netflix.com/Movie/The-Secret-Life-of-Pets/80095314"><img src="//secure.netflix.com/us/boxshots/small/80095314.jpg"/></a><br>Living an easy life, happy terrier Max sees his world upended when his owner brings home Duke, a mongrel Max regards as a loser. But the two soon find themselves allied against a horde of abandoned pets looking to turn the tables on humans.',
#   'summary_detail': {'base': 'http://dvd.netflix.com/Top100RSS',
#    'language': None,
#    'type': 'text/html',
#    'value': '<a href="https://dvd.netflix.com/Movie/The-Secret-Life-of-Pets/80095314"><img src="//secure.netflix.com/us/boxshots/small/80095314.jpg"/></a><br>Living an easy life, happy terrier Max sees his world upended when his owner brings home Duke, a mongrel Max regards as a loser. But the two soon find themselves allied against a horde of abandoned pets looking to turn the tables on humans.'},
#   'title': 'The Secret Life of Pets',
#   'title_detail': {'base': 'http://dvd.netflix.com/Top100RSS',
#    'language': None,
#    'type': 'text/plain',
#    'value': 'The Secret Life of Pets'}},
#  {'guidislink': False,
#   'id': 'https://dvd.netflix.com/Movie/Free-State-of-Jones/80080158',
#   'link': 'https://dvd.netflix.com/Movie/Free-State-of-Jones/80080158',
#   'links': [{'href': 'https://dvd.netflix.com/Movie/Free-State-of-Jones/80080158',
#     'rel': 'alternate',
#     'type': 'text/html'}],
#   'summary': '<a href="https://dvd.netflix.com/Movie/Free-State-of-Jones/80080158"><img src="//secure.netflix.com/us/boxshots/small/80080158.jpg"/></a><br>As the Civil War rages on, Mississippi farmer Newton Knight, his neighbors and a ragtag group of slaves band together and lead Jones County to secede from the Confederacy, establishing a mixed-race free state in the heart of the South.',
#   'summary_detail': {'base': 'http://dvd.netflix.com/Top100RSS',
#    'language': None,
#    'type': 'text/html',
#    'value': '<a href="https://dvd.netflix.com/Movie/Free-State-of-Jones/80080158"><img src="//secure.netflix.com/us/boxshots/small/80080158.jpg"/></a><br>As the Civil War rages on, Mississippi farmer Newton Knight, his neighbors and a ragtag group of slaves band together and lead Jones County to secede from the Confederacy, establishing a mixed-race free state in the heart of the South.'},
#   'title': 'Free State of Jones',
#   'title_detail': {'base': 'http://dvd.netflix.com/Top100RSS',
#    'language': None,
#    'type': 'text/plain',
#    'value': 'Free State of Jones'}},
#  {'guidislink': False,
#   'id': 'https://dvd.netflix.com/Movie/Florence-Foster-Jenkins/80080480',
#   'link': 'https://dvd.netflix.com/Movie/Florence-Foster-Jenkins/80080480',
#   'links': [{'href': 'https://dvd.netflix.com/Movie/Florence-Foster-Jenkins/80080480',
#     'rel': 'alternate',
#     'type': 'text/html'}],
#   'summary': '<a href="https://dvd.netflix.com/Movie/Florence-Foster-Jenkins/80080480"><img src="//secure.netflix.com/us/boxshots/small/80080480.jpg"/></a><br>Despite her horrid singing voice, New York City heiress Florence Foster Jenkins is certain she can become an opera star. Her partner and manager, St Clair Bayfield, does all he can to shield Florence from the truth, but his task may prove impossible.',
#   'summary_detail': {'base': 'http://dvd.netflix.com/Top100RSS',
#    'language': None,
#    'type': 'text/html',
#    'value': '<a href="https://dvd.netflix.com/Movie/Florence-Foster-Jenkins/80080480"><img src="//secure.netflix.com/us/boxshots/small/80080480.jpg"/></a><br>Despite her horrid singing voice, New York City heiress Florence Foster Jenkins is certain she can become an opera star. Her partner and manager, St Clair Bayfield, does all he can to shield Florence from the truth, but his task may prove impossible.'},
#   'title': 'Florence Foster Jenkins',
#   'title_detail': {'base': 'http://dvd.netflix.com/Top100RSS',
#    'language': None,
#    'type': 'text/plain',
#    'value': '
',
#   'summary_detail': {'base': 'http://dvd.netflix.com/Top100RSS',
#    'language': None,
#    'type': 'text/html',
#    'value': '<a href="https://dvd.netflix.com/Movie/Lion/80108447"><img src="//secure.netflix.com/us/boxshots/small/80108447.jpg"/></a><br>In this affecting true story, 5-year-old Saroo is adopted by an Australian couple after losing his way in the urban jungle of Kolkata. More than two decades later, new mapping technology prompts Saroo to search for his lost family in India.'},
#   'title': 'Lion',
#   'title_detail': {'base': 'http://dvd.netflix.com/Top100RSS',
#    'language': None,
#    'type': 'text/plain',
#    'value': 'Lion'}},
#  {'guidislink': False,
#   'id': 'https://dvd.netflix.com/Movie/Star-Trek-Beyond/80096630',
#   'link': 'https://dvd.netflix.com/Movie/Star-Trek-Beyond/80096630',
#   'links': [{'href': 'https://dvd.netflix.com/Movie/Star-Trek-Beyond/80096630',
#     'rel': 'alternate',
#     'type': 'text/html'}],
#   'summary': '<a href="https://dvd.netflix.com/Movie/Star-Trek-Beyond/80096630"><img src="//secure.netflix.com/us/boxshots/small/80096630.jpg"/></a><br>Released to coincide with the 50th anniversary of the iconic "Star Trek" franchise, this action-packed space adventure adds to the legend of Capt. Kirk and his crew, who end up marooned on a remote planet after the "Enterprise" is destroyed.',
#   'summary_detail': {'base': 'http://dvd.netflix.com/Top100RSS',
#    'language': None,
#    'type': 'text/html',
#    'value': '<a href="https://dvd.netflix.com/Movie/Star-Trek-Beyond/80096630"><img src="//secure.netflix.com/us/boxshots/small/80096630.jpg"/></a><br>Released to coincide with the 50th anniversary of the iconic "Star Trek" franchise, this action-packed space adventure adds to the legend of Capt. Kirk and his crew, who end up marooned on a remote planet after the "Enterprise" is destroyed.'},
#   'title': 'Star Trek Beyond',
#   'title_detail': {'base': 'http://dvd.netflix.com/Top100RSS',
#    'language': None,
#    'type': 'text/plain',
#    'value': 'Star Trek Beyond'}},
#  {'guidislink': False,
#   'id': 'https://dvd.netflix.com/Movie/Mechanic-Resurrection/80100582',
#   'link': 'https://dvd.netflix.com/Movie/Mechanic-Resurrection/80100582',
#   'links': [{'href': 'https://dvd.netflix.com/Movie/Mechanic-Resurrection/80100582',
#     'rel': 'alternate',
#     'type': 'text/html'}],
#   'summary': '<a href="https://dvd.netflix.com/Movie/Mechanic-Resurrection/80100582"><img src="//secure.netflix.com/us/boxshots/small/80100582.jpg"/></a><br>After swearing off his profession as a contract killer, Arthur Bishop finds that never is a long time when the woman he loves is abducted by an old nemesis -- and the only way to save her is to complete a string of hits.',
#   'summary_detail': {'base': 'http://dvd.netflix.com/Top100RSS',
#    'language': None,
#    'type': 'text/html',
#    'value': '<a href="https://dvd.netflix.com/Movie/Mechanic-Resurrection/80100582"><img src="//secure.netflix.com/us/boxshots/small/80100582.jpg"/></a><br>After swearing off his profession as a contract killer, Arthur Bishop finds that never is a long time when the woman he loves is abducted by an old nemesis -- and the only way to save her is to complete a string of hits.'},
#   'title': 'Mechanic: Resurrection',
#   'title_detail': {'base': 'http://dvd.netflix.com/Top100RSS',
#    'language': None,
#    'type': 'text/plain',
#    'value': 'Mechanic: Resurrection'}},
#  {'guidislink': False,
#   'id': 'https://dvd.netflix.com/Movie/La-La-Land/80095365',
#   'link': 'https://dvd.netflix.com/Movie/La-La-Land/80095365',
#   'links': [{'href': 'https://dvd.netflix.com/Movie/La-La-Land/80095365',
#     'rel': 'alternate',
#     'type': 'text/html'}],
#   'summary': '<a href="https://dvd.netflix.com/Movie/La-La-Land/80095365"><img src="//secure.netflix.com/us/boxshots/small/80095365.jpg"/></a><br>While pursuing showbiz fame, jazz pianist Sebastian falls for aspiring actress Mia, and the two embark on an intense love affair. But as their separate paths of ambition force them to make tough choices, their relationship starts to fray.',
#   'summary_detail': {'base': 'http://dvd.netflix.com/Top100RSS',
#    'language': None,
#    'type': 'text/html',
#    'value': '<a href="https://dvd.netflix.com/Movie/La-La-Land/80095365"><img src="//secure.netflix.com/us/boxshots/small/80095365.jpg"/></a><br>While pursuing showbiz fame, jazz pianist Sebastian falls for aspiring actress Mia, and the two embark on an intense love affair. But as their separate paths of ambition force them to make tough choices, their relationship starts to fray.'},
#   'title': 'La La Land',
#   'title_detail': {'base': 'http://dvd.netflix.com/Top100RSS',
#    'language': None,
#    'type': 'text/plain',
#    'value': 'La La Land'}},
#  {'guidislink': False,
#   'id': 'https://dvd.netflix.com/Movie/Moonlight/80121348',
#   'link': 'https://dvd.netflix.com/Movie/Moonlight/80121348',
#   'links': [{'href': 'https://dvd.netflix.com/Movie/Moonlight/80121348',
#     'rel': 'alternate',
#     'type': 'text/html'}],
#   'summary': '<a href="https://dvd.netflix.com/Movie/Moonlight/80121348"><img src="//secure.netflix.com/us/boxshots/small/80121348.jpg"/></a><br>Growing up in the drug-soaked world of 1980s Miami, young Chiron struggles to make his way through a helter-skelter adolescence while also grappling with confusion and anxiety about his emerging sexuality.',
#   'summary_detail': {'base': 'http://dvd.netflix.com/Top100RSS',
#    'language': None,
#    'type': 'text/html',
#    'value': '<a href="https://dvd.netflix.com/Movie/Moonlight/80121348"><img src="//secure.netflix.com/us/boxshots/small/80121348.jpg"/></a><br>Growing up in the drug-soaked world of 1980s Miami, young Chiron struggles to make his way through a helter-skelter adolescence while also grappling with confusion and anxiety about his emerging sexuality.'},
#   'title': 'Moonlight',
#   'title_detail': {'base': 'http://dvd.netflix.com/Top100RSS',
#    'language': None,
#    'type': 'text/plain',
#    'value': 'Moonlight'}},
#  {'guidislink': False,
#   'id': 'https://dvd.netflix.com/Movie/Independence-Day-Resurgence/80094621',
#   'link': 'https://dvd.netflix.com/Movie/Independence-Day-Resurgence/80094621',
#   'links': [{'href': 'https://dvd.netflix.com/Movie/Independence-Day-Resurgence/80094621',
#     'rel': 'alternate',
#     'type': 'text/html'}],
#   'summary': '<a href="https://dvd.netflix.com/Movie/Independence-Day-Resurgence/80094621"><img src="//secure.netflix.com/us/boxshots/small/80094621.jpg"/></a><br>Twenty years after the initial invasion of Earth by an army of advanced extraterrestrials, the same foes attack again with redoubled force, forcing humankind to construct defenses cobbled from alien technology left behind after the original attack.',
#   'summary_detail': {'base': 'http://dvd.netflix.com/Top100RSS',
#    'language': None,
#    'type': 'text/html',
#    'value': '<a href="https://dvd.netflix.com/Movie/Independence-Day-Resurgence/80094621"><img src="//secure.netflix.com/us/boxshots/small/80094621.jpg"/></a><br>Twenty years after the initial invasion of Earth by an army of advanced extraterrestrials, the same foes attack again with redoubled force, forcing humankind to construct defenses cobbled from alien technology left behind after the original attack.'},
#   'title': 'Independence Day: Resurgence',
#   'title_detail': {'base': 'http://dvd.netflix.com/Top100RSS',
#    'language': None,
#    'type': 'text/plain',
#    'value': 'Independence Day: Resurgence'}},
#  {'guidislink': False,
#   'id': 'https://dvd.netflix.com/Movie/Finding-Dory/80094319',
#   'link': 'https://dvd.netflix.com/Movie/Finding-Dory/80094319',
#   'links': [{'href': 'https://dvd.netflix.com/Movie/Finding-Dory/80094319',
#     'rel': 'alternate',
#     'type': 'text/html'}],
#   'summary': '<a href="https://dvd.netflix.com/Movie/Finding-Dory/80094319"><img src="//secure.netflix.com/us/boxshots/small/80094319.jpg"/></a><br>When Dory, the forgetful blue tang (Ellen DeGeneres), suddenly remembers she has a family who may be looking for her, she, Marlin (Albert Brooks) and Nemo (Hayden Rolence) take off on a life-changing quest to find them.',
#   'summary_detail': {'base': 'http://dvd.netflix.com/Top100RSS',
#    'language': None,
#    'type': 'text/html',
#    'value': '<a href="https://dvd.netflix.com/Movie/Finding-Dory/80094319"><img src="//secure.netflix.com/us/boxshots/small/80094319.jpg"/></a><br>When Dory, the forgetful blue tang (Ellen DeGeneres), suddenly remembers she has a family who may be looking for her, she, Marlin (Albert Brooks) and Nemo (Hayden Rolence) take off on a life-changing quest to find them.'},
#   'title': 'Finding Dory',
#   'title_detail': {'base': 'http://dvd.netflix.com/Top100RSS',
#    'language': None,
#    'type': 'text/plain',
#    'value': 'Finding Dory'}},
#  {'guidislink': False,
#   'id': 'https://dvd.netflix.com/Movie/Snowden/80064514',
#   'link': 'https://dvd.netflix.com/Movie/Snowden/80064514',
#   'links': [{'href': 'https://dvd.netflix.com/Movie/Snowden/80064514',
#     'rel': 'alternate',
#     'type': 'text/html'}],
#   'summary': '<a href="https://dvd.netflix.com/Movie/Snowden/80064514"><img src="//secure.netflix.com/us/boxshots/small/80064514.jpg"/></a><br>In 2013, CIA technical expert Edward Snowden stunned the world by revealing a stolen trove of classified U.S. government documents. This Oliver Stone-helmed drama tells the story of the bold theft that exposed secret NSA mass surveillance programs.',
#   'summary_detail': {'base': 'http://dvd.netflix.com/Top100RSS',
#    'language': None,
#    'type': 'text/html',
#    'value': '<a href="https://dvd.netflix.com/Movie/Snowden/80064514"><img src="//secure.netflix.com/us/boxshots/small/80064514.jpg"/></a><br>In 2013, CIA technical expert Edward Snowden stunned the world by revealing a stolen trove of classified U.S. government documents. This Oliver Stone-helmed drama tells the story of the bold theft that exposed secret NSA mass surveillance programs.'},
#   'title': 'Snowden',
#   'title_detail': {'base': 'http://dvd.netflix.com/Top100RSS',
#    'language': None,
#    'type': 'text/plain',
#    'value': 'Snowden'}},
#  {'guidislink': False,
#   'id': 'https://dvd.netflix.com/Movie/Money-Monster/80084089',
#   'link': 'https://dvd.netflix.com/Movie/Money-Monster/80084089',
#   'links': [{'href': 'https://dvd.netflix.com/Movie/Money-Monster/80084089',
#     'rel': 'alternate',
#     'type': 'text/html'}],
#   'summary': '<a href="https://dvd.netflix.com/Movie/Money-Monster/80084089"><img src="//secure.netflix.com/us/boxshots/small/80084089.jpg"/></a><br>Landing in dire financial straits after following a stock tip from bombastic TV persona Lee Gates, fuming Kyle Budwell takes the lout hostage on live television and threatens to kill him unless he turns the stock price around before the closing bell.',
#   'summary_detail': {'base': 'http://dvd.netflix.com/Top100RSS',
#    'language': None,
#    'type': 'text/html',
#    'value': '<a href="https://dvd.netflix.com/Movie/Money-Monster/80084089"><img src="//secure.netflix.com/us/boxshots/small/80084089.jpg"/></a><br>Landing in dire financial straits after following a stock tip from bombastic TV persona Lee Gates, fuming Kyle Budwell takes the lout hostage on live television and threatens to kill him unless he turns the stock price around before the closing bell.'},
#   'title': 'Money Monster',
#   'title_detail': {'base': 'http://dvd.netflix.com/Top100RSS',
#    'language': None,
#    'type': 'text/plain',
#    'value': 'Money Monster'}},
#  {'guidislink': False,
#   'id': 'https://dvd.netflix.com/Movie/Hidden-Figures/80123775',
#   'link': 'https://dvd.netflix.com/Movie/Hidden-Figures/80123775',
#   'links': [{'href': 'https://dvd.netflix.com/Movie/Hidden-Figures/80123775',
#     'rel': 'alternate',
#     'type': 'text/html'}],
#   'summary': '<a href="https://dvd.netflix.com/Movie/Hidden-Figures/80123775"><img src="//secure.netflix.com/us/boxshots/small/80123775.jpg"/></a><br>In the race to space between the United States and the Soviet Union during the Cold War, three black female mathematicians play a key role in launching astronaut John Glenn into outer space, making him the first American to orbit Earth.',
#   'summary_detail': {'base': 'http://dvd.netflix.com/Top100RSS',
#    'language': None,
#    'type': 'text/html',
#    'value': '<a href="https://dvd.netflix.com/Movie/Hidden-Figures/80123775"><img src="//secure.netflix.com/us/boxshots/small/80123775.jpg"/></a><br>In the race to space between the United States and the Soviet Union during the Cold War, three black female mathematicians play a key role in launching astronaut John Glenn into outer space, making him the first American to orbit Earth.'},
#   'title': 'Hidden Figures',
#   'title_detail': {'base': 'http://dvd.netflix.com/Top100RSS',
#    'language': None,
#    'type': 'text/plain',
#    'value': 'Hidden Figures'}},
#  {'guidislink': False,
#   'id': 'https://dvd.netflix.com/Movie/Central-Intelligence/80094318',
#   'link': 'https://dvd.netflix.com/Movie/Central-Intelligence/80094318',
#   'links': [{'href': 'https://dvd.netflix.com/Movie/Central-Intelligence/80094318',
#     'rel': 'alternate',
#     'type': 'text/html'}],
#   'summary': '<a href="https://dvd.netflix.com/Movie/Central-Intelligence/80094318"><img src="//secure.netflix.com/us/boxshots/small/80094318.jpg"/></a><br>When a career accountant reconnects with a former classmate who now works as a CIA operative, the mild-mannered number-cruncher soon finds himself waist deep in a lethal counterespionage operation.',
#   'summary_detail': {'base': 'http://dvd.netflix.com/Top100RSS',
#    'language': None,
#    'type': 'text/html',
#    'value': '<a href="https://dvd.netflix.com/Movie/Central-Intelligence/80094318"><img src="//secure.netflix.com/us/boxshots/small/80094318.jpg"/></a><br>When a career accountant reconnects with a former classmate who now works as a CIA operative, the mild-mannered number-cruncher soon finds himself waist deep in a lethal counterespionage operation.'},
#   'title': 'Central Intelligence',
#   'title_detail': {'base': 'http://dvd.netflix.com/Top100RSS',
#    'language': None,
#    'type': 'text/plain',
# ...
#   'title': 'The Finest Hours',
#   'title_detail': {'base': 'http://dvd.netflix.com/Top100RSS',
#    'language': None,
#    'type': 'text/plain',
#    'value': 'The Finest Hours'}},
#  {'guidislink': False,
#   'id': 'https://dvd.netflix.com/Movie/Captain-America-Civil-War/80088567',
#   'link': 'https://dvd.netflix.com/Movie/Captain-America-Civil-War/80088567',
#   'links': [{'href': 'https://dvd.netflix.com/Movie/Captain-America-Civil-War/80088567',
#     'rel': 'alternate',
#     'type': 'text/html'}],
#   'summary': '<a href="https://dvd.netflix.com/Movie/Captain-America-Civil-War/80088567"><img src="//secure.netflix.com/us/boxshots/small/80088567.jpg"/></a><br>The most explosive clash to ever rock the Marvel Cinematic Universe ignites a firestorm of conflict in the game-changing epic, Captain America: Civil War. In the wake of collateral damage, government pressure to rein in the Avengers drives a deep wedge between Captain America and Iron Man, causing a catastrophic rift that turns the two friends into bitter enemies. Against a backdrop of divided loyalties, their fellow Avengers must deal with the fallout.',
#   'summary_detail': {'base': 'http://dvd.netflix.com/Top100RSS',
#    'language': None,
#    'type': 'text/html',
#    'value': '<a href="https://dvd.netflix.com/Movie/Captain-America-Civil-War/80088567"><img src="//secure.netflix.com/us/boxshots/small/80088567.jpg"/></a><br>The most explosive clash to ever rock the Marvel Cinematic Universe ignites a firestorm of conflict in the game-changing epic, Captain America: Civil War. In the wake of collateral damage, government pressure to rein in the Avengers drives a deep wedge between Captain America and Iron Man, causing a catastrophic rift that turns the two friends into bitter enemies. Against a backdrop of divided loyalties, their fellow Avengers must deal with the fallout.'},
#   'title': 'Captain America: Civil War',
#   'title_detail': {'base': 'http://dvd.netflix.com/Top100RSS',
#    'language': None,
#    'type': 'text/plain',
#    'value': 'Captain America: Civil War'}},
#  {'guidislink': False,
#   'id': 'https://dvd.netflix.com/Movie/Neighbors-2-Sorority-Rising/80091747',
#   'link': 'https://dvd.netflix.com/Movie/Neighbors-2-Sorority-Rising/80091747',
#   'links': [{'href': 'https://dvd.netflix.com/Movie/Neighbors-2-Sorority-Rising/80091747',
#     'rel': 'alternate',
#     'type': 'text/html'}],
#   'summary': '<a href="https://dvd.netflix.com/Movie/Neighbors-2-Sorority-Rising/80091747"><img src="//secure.netflix.com/us/boxshots/small/80091747.jpg"/></a><br>Revisiting the comedic chaos of the original, this rollicking sequel finds Teddy and Pete coming to the Radner family\'s rescue, wading into battle with the wild sorority sisters now occupying the duo\'s former fraternity house.',
#   'summary_detail': {'base': 'http://dvd.netflix.com/Top100RSS',
#    'language': None,
#    'type': 'text/html',
#    'value': '<a href="https://dvd.netflix.com/Movie/Neighbors-2-Sorority-Rising/80091747"><img src="//secure.netflix.com/us/boxshots/small/80091747.jpg"/></a><br>Revisiting the comedic chaos of the original, this rollicking sequel finds Teddy and Pete coming to the Radner family\'s rescue, wading into battle with the wild sorority sisters now occupying the duo\'s former fraternity house.'},
#   'title': 'Neighbors 2: Sorority Rising',
#   'title_detail': {'base': 'http://dvd.netflix.com/Top100RSS',
#    'language': None,
#    'type': 'text/plain',
#    'value': 'Neighbors 2: Sorority Rising'}},
#  {'guidislink': False,
#   'id': 'https://dvd.netflix.com/Movie/
',
#   'summary_detail': {'base': 'http://dvd.netflix.com/Top100RSS',
#    'language': None,
#    'type': 'text/html',
#    'value': '<a href="https://dvd.netflix.com/Movie/Bridge-of-Spies/80050060"><img src="//secure.netflix.com/us/boxshots/small/80050060.jpg"/></a><br>At the height of the Cold War in 1960, the downing of an American spy plane and the pilot\'s subsequent capture by the Soviets draws Brooklyn attorney James Donovan into the middle of an intense effort to secure the aviator\'s release.'},
#   'title': 'Bridge of Spies',
#   'title_detail': {'base': 'http://dvd.netflix.com/Top100RSS',
#    'language': None,
#    'type': 'text/plain',
#    'value': 'Bridge of Spies'}},
#  {'guidislink': False,
#   'id': 'https://dvd.netflix.com/Movie/Mr-Church/80131551',
#   'link': 'https://dvd.netflix.com/Movie/Mr-Church/80131551',
#   'links': [{'href': 'https://dvd.netflix.com/Movie/Mr-Church/80131551',
#     'rel': 'alternate',
#     'type': 'text/html'}],
#   'summary': '<a href="https://dvd.netflix.com/Movie/Mr-Church/80131551"><img src="//secure.netflix.com/us/boxshots/small/80131551.jpg"/></a><br>Hired to lend a hand to a single mother diagnosed with cancer, Henry Joseph Church wins the hearts of mom Marie Brody and daughter Charlie through his cooking, establishing a bond that lasts long beyond Marie\'s death and Charlie\'s childhood.',
#   'summary_detail': {'base': 'http://dvd.netflix.com/Top100RSS',
#    'language': None,
#    'type': 'text/html',
#    'value': '<a href="https://dvd.netflix.com/Movie/Mr-Church/80131551"><img src="//secure.netflix.com/us/boxshots/small/80131551.jpg"/></a><br>Hired to lend a hand to a single mother diagnosed with cancer, Henry Joseph Church wins the hearts of mom Marie Brody and daughter Charlie through his cooking, establishing a bond that lasts long beyond Marie\'s death and Charlie\'s childhood.'},
#   'title': 'Mr. Church',
#   'title_detail': {'base': 'http://dvd.netflix.com/Top100RSS',
#    'language': None,
#    'type': 'text/plain',
#    'value': 'Mr. Church'}},
#  {'guidislink': False,
#   'id': 'https://dvd.netflix.com/Movie/USS-Indianapolis-Men-of-Courage/80108976',
#   'link': 'https://dvd.netflix.com/Movie/USS-Indianapolis-Men-of-Courage/80108976',
#   'links': [{'href': 'https://dvd.netflix.com/Movie/USS-Indianapolis-Men-of-Courage/80108976',
#     'rel': 'alternate',
#     'type': 'text/html'}],
#   'summary': '<a href="https://dvd.netflix.com/Movie/USS-Indianapolis-Men-of-Courage/80108976"><img src="//secure.netflix.com/us/boxshots/small/80108976.jpg"/></a><br>After delivering the weapons that will end World War II, the "USS Indianapolis" crew is denied the celebration of a mission accomplished when their ship is sunk by the Japanese. Stranded at sea, the survivors face hunger, thirst and shark attacks.',
#   'summary_detail': {'base': 'http://dvd.netflix.com/Top100RSS',
#    'language': None,
#    'type': 'text/html',
#    'value': '<a href="https://dvd.netflix.com/Movie/USS-Indianapolis-Men-of-Courage/80108976"><img src="//secure.netflix.com/us/boxshots/small/80108976.jpg"/></a><br>After delivering the weapons that will end World War II, the "USS Indianapolis" crew is denied the celebration of a mission accomplished when their ship is sunk by the Japanese. Stranded at sea, the survivors face hunger, thirst and shark attacks.'},
#   'title': 'USS Indianapolis: Men of Courage',
#   'title_detail': {'base': 'http://dvd.netflix.com/Top100RSS',
#    'language': None,
#    'type': 'text/plain',
#    'value': 'USS Indianapolis: Men of Courage'}},
#  {'guidislink': False,
#   'id': 'https://dvd.netflix.com/Movie/The-Meddler/80077229',
#   'link': 'https://dvd.netflix.com/Movie/The-Meddler/80077229',
#   'links': [{'href': 'https://dvd.netflix.com/Movie/The-Meddler/80077229',
#     'rel': 'alternate',
#     'type': 'text/html'}],
#   'summary': '<a href="https://dvd.netflix.com/Movie/The-Meddler/80077229"><img src="//secure.netflix.com/us/boxshots/small/80077229.jpg"/></a><br>On the heels of her husband\'s death, Marnie Minervini moves to Los Angeles and begins interfering with her daughter Lori\'s life. But after Marnie\'s chance encounter with a charismatic security guard, she turns her attention in a different direction.',
#   'summary_detail': {'base': 'http://dvd.netflix.com/Top100RSS',
#    'language': None,
#    'type': 'text/html',
#    'value': '<a href="https://dvd.netflix.com/Movie/The-Meddler/80077229"><img src="//secure.netflix.com/us/boxshots/small/80077229.jpg"/></a><br>On the heels of her husband\'s death, Marnie Minervini moves to Los Angeles and begins interfering with her daughter Lori\'s life. But after Marnie\'s chance encounter with a charismatic security guard, she turns her attention in a different direction.'},
#   'title': 'The Meddler',
#   'title_detail': {'base': 'http://dvd.netflix.com/Top100RSS',
#    'language': None,
#    'type': 'text/plain',
#    'value': 'The Meddler'}},
#  {'guidislink': False,
#   'id': 'https://dvd.netflix.com/Movie/Batman-v-Superman-Dawn-of-Justice/80081793',
#   'link': 'https://dvd.netflix.com/Movie/Batman-v-Superman-Dawn-of-Justice/80081793',
#   'links': [{'href': 'https://dvd.netflix.com/Movie/Batman-v-Superman-Dawn-of-Justice/80081793',
#     'rel': 'alternate',
#     'type': 'text/html'}],
#   'summary': '<a href="https://dvd.netflix.com/Movie/Batman-v-Superman-Dawn-of-Justice/80081793"><img src="//secure.netflix.com/us/boxshots/small/80081793.jpg"/></a><br>Superegos battle in superhero fashion while a new threat emerges in this sequel to "Man of Steel." With Batman decamping Gotham City for Metropolis to take on a Superman who\'s become too powerful, trouble brews for the rest of humanity.',
#   'summary_detail': {'base': 'http://dvd.netflix.com/Top100RSS',
#    'language': None,
#    'type': 'text/html',
#    'value': '<a href="https://dvd.netflix.com/Movie/Batman-v-Superman-Dawn-of-Justice/80081793"><img src="//secure.netflix.com/us/boxshots/small/80081793.jpg"/></a><br>Superegos battle in superhero fashion while a new threat emerges in this sequel to "Man of Steel." With Batman decamping Gotham City for Metropolis to take on a Superman who\'s become too powerful, trouble brews for the rest of humanity.'},
#   'title': 'Batman v Superman: Dawn of Justice',
#   'title_detail': {'base': 'http://dvd.netflix.com/Top100RSS',
#    'language': None,
#    'type': 'text/plain',
#    'value': 'Batman v Superman: Dawn of Justice'}}]

# %%
# The entries method returns a python list! Each item within this list is a python dict. 
isinstance(netflix_parse.entries, list)
# Out:
# True

# %%
# We can search each entry in the list, and pull out the metadata using the feed keys as methods (title, link, summary, etc) 
netflix_parse.entries[0].title
# Out:
# 'Sully'

# %%
netflix_parse.entries[0].summary
# Out:
# '<a href="https://dvd.netflix.com/Movie/Sully/80103102"><img src="//secure.netflix.com/us/boxshots/small/80103102.jpg"/></a><br>Viewers around the world were astonished in 2009 when airline pilot Chesley Sullenberger safely landed an Airbus 320 on the Hudson River after both engines were disabled. This fact-based drama illuminates Sullenberger\'s life and heroic achievement.'

# %%
netflix_parse.entries[0].links
# Out:
# [{'href': 'https://dvd.netflix.com/Movie/Sully/80103102',
#   'rel': 'alternate',
#   'type': 'text/html'}]

# %% [markdown]
# <b> Now that we have an idea of the structure of the feedparser.parse object, we can go back to the function top10_movies... </b>
# <b> We can modify it to a more generic function, able to parse other RSS feeds. Then move on to the API notebook!! </b>

# %%
def topX_movies(rss, dfcolumns, entrylimit):
     '''This function extracts data from an rss feed and returns that data as a pandas dataframe object. / 
             
        rss (type: str) is a link to the rss stream to parse with feedparser 
        dfcolumns (type: list) contains the values to collect from each entry in the rss stream
        entrylimit (type: int) is the number of entries to collect from the rss stream
        
        '''
    
    #step1. pull rss feed
    rss_parse = feedparser.parse(rss)
    
    #step2. check rss feed integrity. tell us the result
    if 'bozo' in rss_parse.feed and rss_parse.bozo == 0:
        print('The RSS format is good!')
    else:
        print('The RSS format is not good. Be careful when using this data!') 
      
    #step3. create global counter to wrap code in a loop. we need to pull data for each entry.
    i = 0
       
    #step4. check if passed column values exist in the rss feed. create list with valid columns names. 
    valid_columns = [_ for _ in dfcolumns if _ in rss_parse.entries[0]]
    
    #step5. create dataframe with columns names present in the rss feed. dataframe values are placeholders.
    placeholder_dict = {valid_columns[_]:'not a real entry' for _ in range(len(valid_columns))}
    df = pd.DataFrame(placeholder_dict, columns = valid_columns, index = [0])
    
    
    #step6. add desired data to dataframe. loop through each entry until limit reached.
    while i < entrylimit:
        #create dict with rss feed entries by index 
        parsed_dict = rss_parse.entries[i]  
        
        #create series object with desired rss feed values. create list with values for each entry ordered by valid_columns. 
        parsed_items = pd.Series([parsed_dict[_] for _ in valid_columns], valid_columns)

        #append series to dataframe
        df = df.append(parsed_items, ignore_index = True)   
        
        #increment counter
        i+= 1
    
    #step7. drop first row from dataframe. this row contains placeholder values.
    df = df.drop([0])
    
    #step8. return dataframe
    return df

# %% [markdown]
# <b> The cells below were used to prototype features of the function above </b>

# %%
# We need an easy way to check for a key in a dict. Use the 'in' comparator to see if 'bozo' is present!
'bozo' in netflix_parse.feed
# Out:
# False

# %%
# To create a panda's dataframe, we need to create a dict. The keys will be the column names. 
opop = ['not','what','we','want']      #this list is in place of dfcolumns
opop2 = {opop[_]:'not a real entry' for _ in range(len(opop))}
opop2
# Out:
# {'not': 'not a real entry',
#  'want': 'not a real entry',
#  'we': 'not a real entry',
#  'what': 'not a real entry'}

# %%
# To make a dataframe with one row containing all the column names we want, we need to provide an index value.
# Without an index, pandas will throw an exception. In this case, easy to define 0 as index.
fakedf = pd.DataFrame(data = opop2, columns = opop, index = [0])

# %%
# Test dataframe looks good. Move this code to topX_movies to create a placeholder dataframe!
fakedf
# Out:
#                 not              what                we              want
# 0  not a real entry  not a real entry  not a real entry  not a real entry

# %%
# Can we do essentially this psuedocode in python? [rss_parse.entries[i].item for item in dfcolumns]
# rss_parse.entries is a dict! I can store it as a dict and then call the items in dfcolumns as keys to pull the values!!!
i = 2
testdict = netflix_parse.entries[i]
testdict
# Out:
# {'guidislink': False,
#  'id': 'https://dvd.netflix.com/Movie/The-Accountant/80071227',
#  'link': 'https://dvd.netflix.com/Movie/The-Accountant/80071227',
#  'links': [{'href': 'https://dvd.netflix.com/Movie/The-Accountant/80071227',
#    'rel': 'alternate',
#    'type': 'text/html'}],
#  'summary': '<a href="https://dvd.netflix.com/Movie/The-Accountant/80071227"><img src="//secure.netflix.com/us/boxshots/small/80071227.jpg"/></a><br>Offering two very different skills to his clients, a financial forensics expert and trained assassin goes to work for a tech mogul who\'s determined to eliminate those responsible for secretly manipulating the company\'s financial records.',
#  'summary_detail': {'base': 'http://dvd.netflix.com/Top100RSS',
#   'language': None,
#   'type': 'text/html',
#   'value': '<a href="https://dvd.netflix.com/Movie/The-Accountant/80071227"><img src="//secure.netflix.com/us/boxshots/small/80071227.jpg"/></a><br>Offering two very different skills to his clients, a financial forensics expert and trained assassin goes to work for a tech mogul who\'s determined to eliminate those responsible for secretly manipulating the company\'s financial records.'},
#  'title': 'The Accountant',
#  'title_detail': {'base': 'http://dvd.netflix.com/Top100RSS',
#   'language': None,
#   'type': 'text/plain',
#   'value': 'The Accountant'}}

# %%
# This should pull the values in the order of DF_COLUMNS into a new list, which we can pass to pd.Series!!!
# If any key is not present, this will throw error. Need to use only for valid keys!!!
newlist_onlyvalidcolumns_values = [testdict[_] for _ in DF_COLUMNS if _ in testdict]
newlist_onlyvalidcolumns_values
# Out:
# ['The Accountant',
#  'https://dvd.netflix.com/Movie/The-Accountant/80071227',
#  '<a href="https://dvd.netflix.com/Movie/The-Accountant/80071227"><img src="//secure.netflix.com/us/boxshots/small/80071227.jpg"/></a><br>Offering two very different skills to his clients, a financial forensics expert and trained assassin goes to work for a tech mogul who\'s determined to eliminate those responsible for secretly manipulating the company\'s financial records.']

# %%
# Cells below show that only valid keys used to pull entries, and the output had length 3 as expected
newlist_forrsspares = [_ for _ in DF_COLUMNS if _ in testdict]

# %%
len(testdict)
# Out:
# 8

# %%
len(DF_COLUMNS)
# Out:
# 6

# %%
newlist_forrsspares
# Out:
# ['title', 'link', 'summary']

# %%
len(newlist_onlyvalidcolumns_values)
# Out:
# 3

# %%
len(newlist_forrsspares)
# Out:
# 3

# %% [markdown]
# <b> The cells below were used to check the returned value of the function topX_movies </b>

# %%
final_Dfcheck = topX_movies(NETFLIX, DF_COLUMNS, 10)
# Out:
# The RSS format is not good. Be careful when using this data!

# %%
final_Dfcheck
# Out:
#                     title                                               link  \
# 1                   Sully       https://dvd.netflix.com/Movie/Sully/80103102
# 2           Hacksaw Ridge  https://dvd.netflix.com/Movie/Hacksaw-Ridge/80...
# 3          The Accountant  https://dvd.netflix.com/Movie/The-Accountant/8...
# 4            Jason Bourne  https://dvd.netflix.com/Movie/Jason-Bourne/800...
# 5   The Magnificent Seven  https://dvd.netflix.com/Movie/The-Magnificent-...
# 6         Game of Thrones  https://dvd.netflix.com/Movie/Game-of-Thrones/...
# 7   Manchester by the Sea  https://dvd.netflix.com/Movie/Manchester-by-th...
# 8       Deepwater Horizon  https://dvd.netflix.com/Movie/Deepwater-Horizo...
# 9      Hell or High Water  https://dvd.netflix.com/Movie/Hell-or-High-Wat...
# 10  The Girl on the Train  https://dvd.netflix.com/Movie/The-Girl-on-the-...
#
#                                               summary
# 1   <a href="https://dvd.netflix.com/Movie/Sully/8...
# 2   <a href="https://dvd.netflix.com/Movie/Hacksaw...
# 3   <a href="https://dvd.netflix.com/Movie/The-Acc...
# 4   <a href="https://dvd.netflix.com/Movie/Jason-B...
# 5   <a href="https://dvd.netflix.com/Movie/The-Mag...
# 6   <a href="https://dvd.netflix.com/Movie/Game-of...
# 7   <a href="https://dvd.netflix.com/Movie/Manches...
# 8   <a href="https://dvd.netflix.com/Movie/Deepwat...
# 9   <a href="https://dvd.netflix.com/Movie/Hell-or...
# 10  <a href="https://dvd.netflix.com/Movie/The-Gir...

# %%
final20_Dfcheck = topX_movies(NETFLIX, DF_COLUMNS, 20)
final20_Dfcheck
# Out:
# The RSS format is not good. Be careful when using this data!
#                           title  \
# 1                         Sully
# 2                 Hacksaw Ridge
# 3                The Accountant
# 4                  Jason Bourne
# 5         The Magnificent Seven
# 6               Game of Thrones
# 7         Manchester by the Sea
# 8             Deepwater Horizon
# 9            Hell or High Water
# 10        The Girl on the Train
# 11                   Passengers
# 12                      Inferno
# 13                Suicide Squad
# 14                     Homeland
# 15      The Secret Life of Pets
# 16          Free State of Jones
# 17      Florence Foster Jenkins
# 18                      Arrival
# 19  Jack Reacher: Never Go Back
# 20                     Bad Moms
#
#                                                  link  \
# 1        https://dvd.netflix.com/Movie/Sully/80103102
# 2   https://dvd.netflix.com/Movie/Hacksaw-Ridge/80...
# 3   https://dvd.netflix.com/Movie/The-Accountant/8...
# 4   https://dvd.netflix.com/Movie/Jason-Bourne/800...
# 5   https://dvd.netflix.com/Movie/The-Magnificent-...
# 6   https://dvd.netflix.com/Movie/Game-of-Thrones/...
# 7   https://dvd.netflix.com/Movie/Manchester-by-th...
# 8   https://dvd.netflix.com/Movie/Deepwater-Horizo...
# 9   https://dvd.netflix.com/Movie/Hell-or-High-Wat...
# 10  https://dvd.netflix.com/Movie/The-Girl-on-the-...
# 11  https://dvd.netflix.com/Movie/Passengers/80117456
# 12     https://dvd.netflix.com/Movie/Inferno/80107552
# 13  https://dvd.netflix.com/Movie/Suicide-Squad/80...
# 14    https://dvd.netflix.com/Movie/Homeland/70180387
# 15  https://dvd.netflix.com/Movie/The-Secret-Life-...
# 16  https://dvd.netflix.com/Movie/Free-State-of-Jo...
# 17  https://dvd.netflix.com/Movie/Florence-Foster-...
# 18     https://dvd.netflix.com/Movie/Arrival/80117799
# 19  https://dvd.netflix.com/Movie/Jack-Reacher-Nev...
# 20    https://dvd.netflix.com/Movie/Bad-Moms/80100906
#
#                                               summary
# 1   <a href="https://dvd.netflix.com/Movie/Sully/8...
# 2   <a href="https://dvd.netflix.com/Movie/Hacksaw...
# 3   <a href="https://dvd.netflix.com/Movie/The-Acc...
# 4   <a href="https://dvd.netflix.com/Movie/Jason-B...
# 5   <a href="https://dvd.netflix.com/Movie/The-Mag...
# 6   <a href="https://dvd.netflix.com/Movie/Game-of...
# 7   <a href="https://dvd.netflix.com/Movie/Manches...
# 8   <a href="https://dvd.netflix.com/Movie/Deepwat...
# 9   <a href="https://dvd.netflix.com/Movie/Hell-or...
# 10  <a href="https://dvd.netflix.com/Movie/The-Gir...
# 11  <a href="https://dvd.netflix.com/Movie/Passeng...
# 12  <a href="https://dvd.netflix.com/Movie/Inferno...
# 13  <a href="https://dvd.netflix.com/Movie/Suicide...
# 14  <a href="https://dvd.netflix.com/Movie/Homelan...
# 15  <a href="https://dvd.netflix.com/Movie/The-Sec...
# 16  <a href="https://dvd.netflix.com/Movie/Free-St...
# 17  <a href="https://dvd.netflix.com/Movie/Florenc...
# 18  <a href="https://dvd.netflix.com/Movie/Arrival...
# 19  <a href="https://dvd.netflix.com/Movie/Jack-Re...
# 20  <a href="https://dvd.netflix.com/Movie/Bad-Mom...

# %%
final20_Dfcheck.dtypes
# Out:
# title      object
# link       object
# summary    object
# dtype: object

# %%
# We can slice a row from a dataframe by indexing the row
final20_Dfcheck.loc[1][:]
# Out:
# title                                                  Sully
# link            https://dvd.netflix.com/Movie/Sully/80103102
# summary    <a href="https://dvd.netflix.com/Movie/Sully/8...
# Name: 1, dtype: object

# %%
# We can extract a specific value with indexing by row and column
final20_Dfcheck.loc[1]['title']
# Out:
# 'Sully'

# %%
# What output do we get for the summary?
final20_Dfcheck.loc[1]['summary']
# Out:
# '<a href="https://dvd.netflix.com/Movie/Sully/80103102"><img src="//secure.netflix.com/us/boxshots/small/80103102.jpg"/></a><br>Viewers around the world were astonished in 2009 when airline pilot Chesley Sullenberger safely landed an Airbus 320 on the Hudson River after both engines were disabled. This fact-based drama illuminates Sullenberger\'s life and heroic achievement.'

# %%
# What type of object is the summary?
type(final20_Dfcheck.loc[1]['summary'])
# Out:
# str

# %% [markdown]
# <b> We could parse the summary value using regular expressions from re module to extract only the text outside the html &lt;a&gt; href tag...</b>
